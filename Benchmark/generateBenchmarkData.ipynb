# %% [markdown]
# # 设置拐点数据

# %%
import matplotlib.pyplot as plt
import numpy as np
# from DO2DK import DO2DK
# from CKP import CKP

# PMOP系列
# from PMOP import PMOP1
# pmop = PMOP1()
# pmop.Setting(17,8,4,1,-1,1)
# kn_decs = np.asarray([[0.3], [0.7]])   # PMOP1 (A, B, S, P) = (4, 1, -1, 1)

# from PMOP import PMOP2
# pmop = PMOP2()
# M = 8
# D = M+9
# pmop.Setting(D,M,4,1,2,1)     # PMOP2 (A, B, S, P) = (4, 1, 2, 1)
# kn_decs = np.asarray([[0.125], [0.625]])   # PMOP2

# from PMOP import PMOP3
# pmop = PMOP3()
# M = 3
# D = M + 9
# pmop.Setting(D, M, 4, 1, 2, 1)  # PMOP3 (A, B, S, P) = (4, 1, 2, 1)
# kn_decs = np.asarray([[0.125], [0.625]])   # PMOP3

# from PMOP import PMOP4
# pmop = PMOP4()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 6, 1, -1, 1)  # PMOP3 (A, B, S, P) = (6, 1, -1, 1)
# kn_decs = np.asarray([[0.195], [0.725]])     # PMOP4

# from PMOP import PMOP5
# pmop = PMOP5()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 1, 1, 2, 1, 12)
# kn_decs = np.asarray([[0.55], [0.75]])     # PMOP5

# from PMOP import PMOP6
# pmop = PMOP6()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 2, 1, 2, 1)
# kn_decs = np.asarray([[0.5]])     # PMOP6

# from PMOP import PMOP7
# pmop = PMOP7()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 4, 1, 2, 1)
# kn_decs = np.asarray([[0.125], [0.625]])     # PMOP7

# from PMOP import PMOP8
# pmop = PMOP8()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 4, 1, 2, 1)
# kn_decs = np.asarray([[0.250], [0.75]])     # PMOP8

# from PMOP import PMOP9
# pmop = PMOP9()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 4, 1, 2, 1)
# kn_decs = np.asarray([[0.5]])     # PMOP9

# from PMOP import PMOP10
# pmop = PMOP10()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 1, 1, 2, 1, 12)
# kn_decs = np.asarray([[0.55], [0.75]])     # PMOP10

# from PMOP import PMOP11
# pmop = PMOP11()
# M = 8
# D = M+9
# pmop.Setting(D,M,4,1,2,1)
# # kn_decs = np.asarray([[0.125], [0.625]])   # PMOP11-concave
# kn_decs = np.asarray([[0.375], [0.875]])   # PMOP11-convex

# from PMOP import PMOP12
# pmop = PMOP12()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 4, 1, 2, 1)
# kn_decs = np.asarray([[0.250], [0.75]])     # PMOP12

# from PMOP import PMOP13
# pmop = PMOP13()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 2, 1, -2, 1)
# kn_decs = np.asarray([[0.5]])     # PMOP13

# from PMOP import PMOP14
# pmop = PMOP14()
# M = 8
# D = M + 9
# pmop.Setting(D, M, 2, 1, -1, 1)
# kn_decs = np.asarray([[0.5]])     # PMOP14

# PF = pmop.GetPF(3000)
# PF_knees = pmop.GetKnees_in_PF(kn_decs, np.size(kn_decs))
# regions = pmop.GetKneesAround_in_PF(kn_decs, np.size(kn_decs))

from DEBDK import DEB2DK, DEB3DK
# # DEDK系列
M = 2
deb2dk = DEB2DK()
deb2dk.Setting(10,M,4)
PF = deb2dk.GetPF()
kn_decs = np.asarray([[0.5]])
kn_decs = np.asarray([[0.3], [0.7]])
kn_decs = np.asarray([[0.228], [0.5], [0.776]])
kn_decs = np.asarray([[0.15], [0.39], [0.61], [0.85]])
kn_decs = np.asarray([[0.140], [0.320], [0.5], [0.680], [0.860]])
kn_decs = np.asarray([[0.1], [0.235], [0.365], [0.5], [0.635], [0.765], [0.9]])
kn_decs = np.asarray([[0.080], [0.19], [0.290], [0.4], [0.5], [0.6], [0.71], [0.81], [0.92]])
PF_knees = deb2dk.GetKnees_in_PF(kn_decs, np.size(kn_decs))
regions = deb2dk.GetKneesAround_in_PF(kn_decs, np.size(kn_decs))


# deb3dk = DEB3DK()
# deb3dk.Setting(30,3,3)
# PF = deb3dk.GetPF(1000)
# # kn_decs = np.asarray([[0.5]])
# # kn_decs = np.asarray([[0.3], [0.7]])
# kn_decs = np.asarray([[0.2], [0.5], [0.8]])
# # kn_decs = np.asarray([[0.228], [0.5], [0.776]])
# # kn_decs = np.asarray([[0.177], [0.389], [0.611], [0.832]])
# PF_knees = deb3dk.GetKnees_in_PF(kn_decs, np.size(kn_decs))
# regions = deb3dk.GetKneesAround_in_PF(kn_decs, np.size(kn_decs))

# DO2DK
# do2dk = DO2DK()
# do2dk.Setting(10,2,4,1)
# PF = do2dk.GetPF(200)
# kn_decs = np.asarray([[0.5]])
# kn_decs = np.asarray([[0.28931614], [0.71068555]])
# kn_decs = np.asarray([[0.20516317], [0.5], [0.79483691]])
# kn_decs = np.asarray([[0.163], [0.389], [0.611], [0.851]])
# PF_knees = do2dk.GetKnees_in_PF(kn_decs, np.size(kn_decs))
# regions = do2dk.GetKneesAround_in_PF(kn_decs, np.size(kn_decs))


# CKP
# do2dk = CKP()
# do2dk.Setting(30,2,4)
# PF = do2dk.GetPF(100)
# # kn_decs = np.asarray([[0.482]])
# # kn_decs = np.asarray([[0.240], [0.730]])
# # kn_decs = np.asarray([[0.160], [0.5], [0.82]])
# kn_decs = np.asarray([[0.12], [0.37], [0.615], [0.86]])
# PF_knees = do2dk.GetKnees_in_PF(kn_decs, np.size(kn_decs))
# regions = do2dk.GetKneesAround_in_PF(kn_decs, np.size(kn_decs))

print('PF_knees: %d 个' % np.shape(PF_knees)[0])
print(PF_knees)
# Out:
# [[0.25]
#  [0.75]]
# [[0.25]
#  [0.75]]
# PF_knees: 128 个
# [[4.15458966e-10 3.36926075e-09 4.42622183e-08 ... 1.00352648e-04
#   1.31833987e-03 1.73191248e-02]
#  [3.36926075e-09 4.15458966e-10 4.42622183e-08 ... 1.00352648e-04
#   1.31833987e-03 1.73191248e-02]
#  [3.36926075e-09 2.73238007e-08 5.45791401e-09 ... 1.00352648e-04
#   1.31833987e-03 1.73191248e-02]
#  ...
#  [1.18186277e-04 1.45733893e-05 1.55262153e-03 ... 8.13833047e-04
#   1.31833987e-03 2.13559775e-03]
#  [1.18186277e-04 9.58458996e-04 1.91451652e-04 ... 8.13833047e-04
#   1.31833987e-03 2.13559775e-03]
#  [9.58458996e-04 1.18186277e-04 1.91451652e-04 ... 8.13833047e-04
#   1.31833987e-03 2.13559775e-03]]

# %%
if M==2:
    plt.scatter(PF[:, 0], PF[:, 1])
    plt.scatter(regions[:, 0], regions[:, 1], marker="p", c='y', linewidths=2)
    plt.scatter(PF_knees[:, 0], PF_knees[:, 1], marker="x", c='r', linewidths=2)
elif M==3:
    fig = plt.figure(figsize=(14, 10), dpi=50, facecolor='w', edgecolor='k')
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    ax.scatter(PF[:, 0], PF[:, 1], PF[:, 2], marker='.', alpha=0.5, label='$PF$')
    ax.scatter(PF_knees[:, 0], PF_knees[:, 1], PF_knees[:, 2], marker="p", c="r", linewidths=2,  label='$knees$')
    ax.legend(fontsize=24, loc=0)
    ax.tick_params(labelsize=24)
    ax.set_xlabel("$f_1$", fontsize=28)
    ax.set_ylabel("$f_2$", fontsize=28)
    ax.set_zlabel("$f_2$", fontsize=28)
plt.show()

# %%
import os
from pathlib import Path

top_path = "D:\\File\VsCode\\expensiveMaOP_knee"

path = top_path + "\\Benchmark\\PMOP12\\"+str(D)+"D"+str(M)+"M\\A4"
# path = top_path + "\\Benchmark\\DEB2DK\\10D2M\\K4"
# path = top_path + "\\Benchmark\\DEB3DK\\30D3M\\K3(knee9)"
# path = top_path + "\\Benchmark\\CKP\\30D2M\\K4"
# path = top_path + "\\Benchmark\\DO2DK\\10D2M\\K4S1"
my_file = Path(path)
if my_file.exists():
    print('Data already exist!')
else:
    os.makedirs(path)
    np.save(path+"\\PF_knees.npy", PF_knees)
    np.save(path+"\\regions.npy", regions)

# %% [markdown]
# # 高维可视化拐点
#
# 1、雷达图：https://zhuanlan.zhihu.com/p/351424074
#
# 2、横坐标：目标维度，纵坐标：目标值
#
# 3、降到二维可视化——Knee-Based Decision Making and Visualization in Many-Objective Optimization

# %%
def ASR(Objs, Zmin, Zmax):
    N, _ = np.shape(Objs)
    ASR = np.sum((np.tile(Zmax, (N, 1)) - Objs) / np.tile(Zmax-Zmin, (N, 1)), axis=1)
    return ASR

def MMD(Objs, Zmin, Zmax):
    N, _ = np.shape(Objs)
    MMD = np.sum((Objs - np.tile(Zmin, (N, 1))) / np.tile(Zmax-Zmin, (N, 1)), axis=1)
    return MMD

def reductionDimensionObjectives(Objs, Zmin=None, Zmax=None):
    from sklearn.metrics.pairwise import cosine_similarity
    N, M = np.shape(Objs)
    if Zmin is None:
        Zmin = np.min(Objs, axis=0)
    if Zmax is None:
        Zmax = np.max(Objs, axis=0)
    MMDnd = MMD(Zmax.reshape(1, -1), Zmin, Zmax)
    # print(MMDnd)
    MMDx = MMD(Objs, Zmin, Zmax)
    # index of convergence performance
    dp = (np.tile(MMDnd, (N,)) - MMDx) * np.sqrt(M) / M
    # index of diversity performance
    tObjs = (Objs - np.tile(Zmin, (N, 1))) / np.tile(Zmax-Zmin, (N, 1))
    Wc = np.ones((1, M)) * (1/M)
    angle = np.arccos(cosine_similarity((tObjs-np.tile(Zmax, (N, 1))), -Wc))
    dd = np.tan(angle.flatten()) * dp
    return dp, dd

# %%
# loadData
from PMOP import PMOP3
import numpy as np
# PMOP系列
pmop = PMOP3()
M = 3
D = M+9
A = 4
pmop.Setting(D,M,A,1,2,1)
PF = pmop.GetPF(3000)
top_path = "D:\\File\VsCode\\expensiveMaOP_knee"
path = top_path + "\\Benchmark\\PMOP3\\"+str(D)+"D"+str(M)+"M\\A4"


# from DEBDK import DEB2DK, DEB3DK
# # DEDK系列
# M = 2
# deb2dk = DEB2DK()
# deb2dk.Setting(10,M,4)
# PF = deb2dk.GetPF()
# path = top_path + "\\Benchmark\\DEB2DK\\10D2M\\K4"

knees = np.load(path+"\\PF_knees.npy")
regions = np.load(path+"\\regions.npy")

# %%
# print(knees)
tmp =np.append(knees, PF, axis=0)
Zmin = np.min(tmp, axis=0)
Zmax = np.max(tmp, axis=0)
dp, dd = reductionDimensionObjectives(knees, Zmin, Zmax)
dpf, ddf = reductionDimensionObjectives(PF, Zmin, Zmax)
import matplotlib.pyplot as plt

plt.scatter(dpf, ddf, marker='.', c='blue')
plt.scatter(dp, dd, marker='p', c='orange')
# plt.scatter(PF[:, 0], PF[:, 1], marker='.', c='blue')
# plt.scatter(knees[:, 0], knees[:, 1], marker='x', c='orange')
plt.show()
